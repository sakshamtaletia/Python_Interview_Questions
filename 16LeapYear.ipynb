# %%
""" write a function to check if a given year is leap year or not """
# Out:
# ' write a function to check if a given year is leap year or not '

# %%
year = 1900
if (year%4==0 and year%100!=0) or (year%400==0):
    print(True)
else:
    print(False)
# Out:
# False

# %%
def leap_year(year:int)->bool:
    """ 
    Check whether a year is leap year or not

    Args:
        Take year as an integer
    Return:
           Boolean value
    Raise ValueError:
               if year is less then 1582
    """
    if not isinstance(year,int):
        raise TypeError("year must be a integer value")
    if year<1582:
        raise ValueError("year must be later of 1582")
    if (year%4==0 and year%100!=0) or (year%400==0):
        return True
    else:
        return False
if __name__ =="__main__":
    try:
        user_input = 1992
        result= leap_year(user_input)
        print(result)
    except (TypeError , ValueError) as error:
        print("Error", error)
    except Exception as e:
        print(" Unexcepted error")
# Out:
# True
